# %% [markdown]
# ### Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Create Classifier

# %%
face_classifier= cv2.CascadeClassifier('Downloads/object_detection/haarcascade_frontalface_default.xml')

# %% [markdown]
# ### Open Image

# %%
image=cv2.imread(r'C:\Users\GANESAN\Downloads\object_detection\eye_face.jpg')
fix_img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %% [markdown]
# ### Detect Faces

# %%
faces = face_classifier.detectMultiScale(image, 1.3, 5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-36-785817ddd5f6> in <module>
# ----> 1 faces = face_classifier.detectMultiScale(image, 1.3, 5)
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1698: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %% [markdown]
# ### No Faces Detected

# %%
if faces is ():
    print('No faces found')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e3f3a47a50bb> in <module>
# ----> 1 if faces is ():
#       2     print('No faces found')
#
# NameError: name 'faces' is not defined

# %% [markdown]
# ### It's a kind of Magic

# %%
def detect_face(fix_img):
    face_rects=face_classifier.detectMultiScale(fix_img)
    for (x,y,w,h) in face_rects:
        cv2.rectangle(fix_img,
                     (x,y),
                     (x+w,y+h),
                     (255,0,0),
                     10)
    return fix_img

# %%
result = detect_face(fix_img)
plt.imshow(result)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-22-239f374ff67c> in <module>
# ----> 1 result = detect_face(fix_img)
#       2 plt.imshow(result)
#
# <ipython-input-21-f0c6f3bf148b> in detect_face(fix_img)
#       1 def detect_face(fix_img):
# ----> 2     face_rects=face_classifier.detectMultiScale(fix_img)
#       3     for (x,y,w,h) in face_rects:
#       4         cv2.rectangle(fix_img,
#       5                      (x,y),
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1698: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'
